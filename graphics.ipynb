# %% [markdown]
# 1.
# a. Read Melbourne temperature data from following url
# url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv'
# TIP: df = pd.read_csv(url)
#
# b. Convert time to datetime format so that Matplotlib understands it
# c. Draw line plot, scatter plot and bar plot of temperature over the entire time period. Pay attention to figure size, axes labels, figure name, grid lines and line/dot/bar colors. What is the most informative presentation?
# d. Draw a histogram of temperatures over the entire time period. What is the most common daily minimum temperature?
#
# 2.
# Read data mtcars.csv. Draw four panel subplot figure, where panels show the histogram distribution of:
# - Miles per Gallon
# - Cylinders
# - Horsepower
# - Gears
# Pay attention to histogram bins, figure size, axes labels, figure name and grid lines.
#
# Information about the data file content:
#
# # mpg - Miles per Gallon
# # cyl - # of cylinders
# # disp - displacement, in cubic inches
# # hp - horsepower
# # drat - driveshaft ratio (don't really KNOW cars, so if you've got questions - you know what to do. :-D
# # wt - weight
# # qsec - 1/4 mile time; a measure of acceleration
# # vs - 'V' or straight - engine shape
# # am - transmission; auto or manual
# # gear - # of gears
# # carb - # of carburetors

# %%
#1a
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv')
# Out:
#             Date  Temp
# 0     1981-01-01  20.7
# 1     1981-01-02  17.9
# 2     1981-01-03  18.8
# 3     1981-01-04  14.6
# 4     1981-01-05  15.8
# ...          ...   ...
# 3645  1990-12-27  14.0
# 3646  1990-12-28  13.6
# 3647  1990-12-29  13.5
# 3648  1990-12-30  15.7
# 3649  1990-12-31  13.0
#
# [3650 rows x 2 columns]

# %%
#1b
import datetime

time_year = [0] * df.shape[0]
for i in range(df.shape[0]):
    time_year[i] = datetime.datetime.strptime(df['Date'][i], "%Y-%m-%d")

df['time_year'] = time_year

# %%
#1c Line plot
import matplotlib.pyplot as plt

fig, ax = plt.subplots(num=None, figsize=(10,5), dpi=100, facecolor="w")
plt.plot(df['time_year'], df['Temp'])
plt.title('Daily minimum temperature in Melbourne')
plt.grid(True)
plt.xlabel('Year')
plt.ylabel('Temperature')
ax.set_xlim([datetime.date(1981,1,1),datetime.date(1991,1,1)])
ax.set_ylim([0,25])
plt.show()

# %%
#1c Scatter plot
fig, ax = plt.subplots(num=None, figsize=(10,5), dpi=100, facecolor="w")
plt.scatter(df['time_year'], df['Temp'])
plt.title('Daily minimum temperature in Melbourne')
plt.grid(True)
plt.xlabel('Year')
plt.ylabel('Temperature')
ax.set_xlim([datetime.date(1981,1,1),datetime.date(1991,1,1)])
ax.set_ylim([0,25])
plt.show()

# %%
#1c Bar plot

fig, ax = plt.subplots(num=None, figsize=(10,5), dpi=100, facecolor="w")
plt.bar(df['time_year'], df['Temp']) 
plt.title('Daily minimum temperature in Melbourne')
plt.grid(True)
plt.xlabel('Year')
plt.ylabel('Temperature')
ax.set_xlim([datetime.date(1981,1,1),datetime.date(1991,1,1)])
ax.set_ylim([0,25])
plt.show()

# %%
#1d Histogram
import numpy as np
plt.figure(num=None, figsize=(12,4), dpi=100, facecolor="w")
plt.hist(df['Temp'], bins = np.arange(0,27,1))
plt.xlabel('Temperature Celcius')
plt.grid(True)
plt.ylabel('Number of days')
plt.title('Daily minimum temperature in Melbourne')
plt.show()

# %%
#2
data = pd.read_csv('mtcars.csv')
fig, ax = plt.subplots(num=None, figsize=(10,10), dpi=100, facecolor="w")
plt.subplot(2,2,1)
plt.hist(data['mpg'], bins=np.arange(10, 35, 1))
plt.xlabel('Miles per gallon')
plt.ylabel('Count')

plt.subplot(2,2,2)
plt.hist(data['cyl'], bins=np.arange(4, 10, 1))
plt.xlabel('Number of cylinders')
plt.ylabel('Count')

plt.subplot(2,2,3)
plt.hist(data['hp'])
plt.xlabel('Horsepower')
plt.ylabel('Count')

plt.subplot(2,2,4)
plt.hist(data['gear'], bins=np.arange(3, 7, 1))
plt.xlabel('Gear')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8172\739032058.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,2,1)
